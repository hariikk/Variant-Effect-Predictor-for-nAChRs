# %% [markdown]
# # nachr types
#
# | Subfamily | Subfamily Group | Subunit Type | Specific Subunits | Associated Genes |
# | :--- | :--- | :--- | :--- | :--- |
# | **I** | — | Neuronal | $\alpha9, \alpha10$ | *CHRNA9, CHRNA10* |
# | **II** | — | Neuronal | $\alpha7, \alpha8$* | *CHRNA7, CHRNA8* |
# | **III** | Group 1 | Neuronal | $\alpha2, \alpha3, \alpha4, \alpha6$ | *CHRNA2, CHRNA3, CHRNA4, CHRNA6* |
# | **III** | Group 2 | Neuronal | $\beta2, \beta4$ | *CHRNB2, CHRNB4* |
# | **III** | Group 3 | Neuronal | $\beta3, \alpha5$ | *CHRNB3, CHRNA5* |
# | **IV** | — | Muscle | $\alpha1, \beta1, \delta, \gamma, \epsilon$ | *CHRNA1, CHRNB1, CHRND, CHRNG, CHRNE* |
#
# > ***Note:** The $\alpha8$ subunit is present in avian species (chickens) but is not present in humans or mammals.*

# %% [markdown]
# | Receptor Type | Subunit Composition | Main Location | Primary Function / Notes | Ion Permeability | Agonists | Antagonists |
# |:---|:---|:---|:---|:---|:---|:---|
# | **Muscle (adult)** | α1₂β1δε | Neuromuscular junction | Muscle contraction (adult) | Na⁺, K⁺ | Acetylcholine, Carbachol, Suxamethonium, Decamethonium | α-Bungarotoxin, α-Conotoxin, Tubocurarine, Pancuronium |
# | **Muscle (embryonic)** | α1₂β1δγ | Neuromuscular junction | Muscle contraction (embryo) | Na⁺, K⁺ | Acetylcholine, Carbachol | α-Bungarotoxin, Tubocurarine |
# | **Heteromeric CNS** | α4β2 | CNS (cortex, hippocampus) | **Addiction/Reward:** Major subtype for nicotine reward, attention, and addiction pathophysiology. | Na⁺, K⁺ | Nicotine, Cytisine, Varenicline, Epibatidine | Dihydro-β-erythroidine, Mecamylamine, Bupropion |
# | **Ganglion-type** | α3β4 | Autonomic ganglia | Autonomic signaling; EPSP (Excitatory Postsynaptic Potential). | Na⁺, K⁺ | Nicotine, Epibatidine, DMPP | Hexamethonium, Mecamylamine, Trimetaphan |
# | **Homomeric CNS** | α7₅ | CNS and immune cells | **Cognition/Inflammation:** Fast signaling; pro-angiogenic; neuroprotective. | **High Ca²⁺**, Na⁺, K⁺ | Choline, Nicotine, Varenicline, Cytisine | α-Bungarotoxin, Memantine, Methylcaconitine |
# | **Dopaminergic** | α6β2β3 | CNS (VTA, Substantia Nigra) | **Reward/Movement:** Critical for dopamine release and drug behavior. | Na⁺, K⁺ | *General nicotinic agonists* | *General nicotinic antagonists* |
# | **Specific CNS/PNS** | α3β2 | CNS and PNS | Neuronal modulation | Na⁺, K⁺ | *See Heteromeric CNS* | *See Heteromeric CNS* |
# | **Specific PNS** | α6β4 | PNS ganglia | Peripheral signaling | Na⁺, K⁺ | *See Ganglion-type* | *See Ganglion-type* |
# | **Auditory/Immune** | α9α10 | Cochlea / Immune cells | Auditory signaling and immune modulation | Ca²⁺, Na⁺, K⁺ | *Distinct pharmacology* | α-Bungarotoxin, Strychnine* |
# | **Specific CNS** | α2β2 | CNS | Learning and memory | Na⁺, K⁺ | *See Heteromeric CNS* | *See Heteromeric CNS* |

# %% [markdown]
# # important points
# - state-of-the-art machine learning architectures such as Protein Language Models (PLMs) and Graph Neural Networks (GNNs)
# - The human nAChR family is encoded by a multigene superfamily consisting of 16 distinct subunits: the $\alpha$-subunits ($\alpha$1–$\alpha$7, $\alpha$9, $\alpha$10), the $\beta$-subunits ($\beta$1–$\beta$4), and the muscle-specific $\gamma$, $\delta$, and $\varepsilon$ subunits.
# - The assembly of nAChRs is governed by strict "compatibility rules," resulting in a finite set of functional combinations.
# -

# %% [markdown]
# # Roadmap
# # Phase I - Data Colleciton
#
# - NAChRDB (The Primary Anchor): This is the single most valuable resource for this specific research endeavor. NAChRDB contains approximately 2,000 curated residue-level functional annotations derived from 117 studies. It aggregates data on mutagenesis, ligand binding, and electrophysiology. Crucially, it offers a Python-based query interface and allows data export in JSON format, making it machine-readable. The database covers 41 methods, including voltage-clamp and radioligand binding, providing a solid "seed" dataset of known critical residues. Actionable Step: Download the full JSON dump from NAChRDB to establish the baseline schema for the new dataset.
#
# - FireProtDB (Stability Data): While focused on thermodynamic stability rather than channel gating, FireProtDB contains manually curated $\Delta\Delta G$ (Gibbs free energy change) values for single-point mutants. Stability is a major determinant of LoF (misfolded proteins are degraded), making this a vital orthogonal feature set. FireProtDB integrates data from ProTherm and ProtaBank, offering a clean, machine-learning-friendly dataset.
#
# -ClinVar & gnomAD (The Clinical & Population Layer): ClinVar provides the clinical interpretation of variants, while gnomAD provides population allele frequencies. Variants with high frequency in gnomAD can serve as "Benign" functional controls. However, caution is advised: ClinVar labels often reflect clinical syndromes (e.g., Epilepsy) and do not explicitly state the biophysical mechanism (GoF vs. LoF). These labels should be treated as "distal" labels, distinct from the "proximal" labels derived from patch-clamp data

# %% [markdown]
# # Phase II - Targetted LIterature Mining
#
# - Template Query: ("CHRNA7" OR "alpha7") AND ("mutation" OR "variant" OR "substitution") AND ("patch clamp" OR "electrophysiology" OR "IC50" OR "EC50" OR "current density"). Other keywords include Variant Effect Predictor.
#
# -

# %% [markdown]
# # Excel sheet columns
#
# | Column Name | Possibilities |
# | :--- | :--- |
# | **OID** | Integer (1, 2, 3...) |
# | **nAChR subunit** | **Alpha:** CHRNA1, CHRNA2, CHRNA3, CHRNA4, CHRNA5, CHRNA6, CHRNA7, CHRNA9, CHRNA10 <br> **Beta:** CHRNB1, CHRNB2, CHRNB3, CHRNB4 <br> **Muscle:** CHRND ($\delta$), CHRNE ($\epsilon$), CHRNG ($\gamma$) |
# | **Modification type** | Missense, Nonsense, Frameshift, Deletion, Insertion, Duplication, Chimera |
# | **AA position** | Integer (e.g., 248) |
# | **Initial AA** | A, C, D, E, F, G, H, I, K, L, M, N, P, Q, R, S, T, V, W, Y |
# | **New AA** | A, C, D, E, F, G, H, I, K, L, M, N, P, Q, R, S, T, V, W, Y, X (Stop) |
# | **Effect** | Loss of Function (LoF), Gain of Function (GoF), Altered Desensitization, Altered Ca²⁺ Permeability, No Effect, Dominant Negative |
# | **Measuring Technique** | Patch Clamp, Two-Electrode Voltage Clamp (TEVC), Single-Channel Recording, Calcium Imaging, Radioligand Binding |
# | **Pathology** | Congenital Myasthenic Syndrome (CMS), ADNFLE (Epilepsy), Schizophrenia, Nicotine Addiction, Lung Cancer, Autism Spectrum Disorder |
# | **Reference (PMID)** | Integer (e.g., 12345678) |
# | **Entry by** | [Curator Name] |
# | **Correct?** | TRUE, FALSE, Pending |

# %% [markdown]
# # Sequence Alignment
#
# -

# %% [markdown]
# # Database Details(Websites)
#
# 1. [Uniprot][1] - We can use this to search the protein, we then get a lot of information about the particular protein, we scout for the data which we need, which is Mutagenesis. This section contains information of mutations and the change of amino acids, positions, reference links of the publications, methods and such which we require to build our DB. We can cross verify it by manually checking the referenced paper in the website. {Example - search CHRNA7}
#
# 2. [Guide to pharmacology][2] - Each and every protein has their own page and in which there are many detailed information about the protein and also the Mutations and Pathophysiology section in which there are references to papers which does reserach on mutations, we can refer those papers and take it as a verified source of data and add it in our database.
#
# 3. [HGMD][3] - Log in and enable session cookies and navigate through the website to Mutations after searching the required genome and get the inforamation from the references in it. Website might be slow at times.
#
# 4. [VarSome][4] - Have a lot of references when searched for a particular gene, so we can manually go and search for the mutation papers and get the data we want.
#
#
# [1]: https://www.uniprot.org/
# [2]: https://www.guidetopharmacology.org/GRAC/FamilyDisplayForward?familyId=76
# [3]: https://www.hgmd.cf.ac.uk/
# [4]: https://varsome.com/gene/hg38

# %% [markdown]
# Methodology - Use mostly Electrophysiology because it has the accurate ion flow measurements with which we determine the GOF and LOF, RNS and EMG can be used as well because they do give out the LOF or GOF information as an output of their experiment but fail to give the exact values of ion flow and such, any other methods other than this is not compatible for this research

# %% [markdown]
# | Amino Acid | 3-Letter Code | 1-Letter Code | Side Chain Property |
# | :--- | :---: | :---: | :--- |
# | **Alanine** | Ala | A | Non-polar, aliphatic |
# | **Arginine** | Arg | R | Positively charged (Basic) |
# | **Asparagine** | Asn | N | Polar, uncharged |
# | **Aspartic Acid** | Asp | D | Negatively charged (Acidic) |
# | **Cysteine** | Cys | C | Polar, uncharged (contains Sulfur) |
# | **Glutamic Acid** | Glu | E | Negatively charged (Acidic) |
# | **Glutamine** | Gln | Q | Polar, uncharged |
# | **Glycine** | Gly | G | Non-polar (simplest) |
# | **Histidine** | His | H | Positively charged (Basic) |
# | **Isoleucine** | Ile | I | Non-polar, aliphatic |
# | **Leucine** | Leu | L | Non-polar, aliphatic |
# | **Lysine** | Lys | K | Positively charged (Basic) |
# | **Methionine** | Met | M | Non-polar (contains Sulfur) |
# | **Phenylalanine** | Phe | F | Non-polar, aromatic |
# | **Proline** | Pro | P | Non-polar (cyclic structure) |
# | **Serine** | Ser | S | Polar, uncharged |
# | **Threonine** | Thr | T | Polar, uncharged |
# | **Tryptophan** | Trp | W | Non-polar, aromatic |
# | **Tyrosine** | Tyr | Y | Polar, aromatic |
# | **Valine** | Val | V | Non-polar, aliphatic |
