# %%
import pandas as pd

# 1. Provide the actual file name, removing the "~$"
source_path = r'C:\Users\harik\Downloads\Computational Chemistry\Variant-Effect-Predictor-for-nAChRs\nachr_db_manual.xlsx'

# 2. Use read_excel for .xlsx files
# Note: You may need to run `pip install openpyxl` in your terminal if you haven't yet, 
# as pandas needs that engine to read modern Excel files.
df = pd.read_excel(source_path)

# 3. Print out the exact column names
print("--- Exact Column Names ---")
print(df.columns.tolist())

technique_counts = df['Measuring Technique'].value_counts(dropna=False)
print(technique_counts)
# Out:
# --- Exact Column Names ---
# ['OID', 'nAChR subunit', 'Modification type', 'AA position', 'Initial AA', 'New AA', 'Effect', 'Measuring Technique', 'Pathology', 'Reference(PMID)', 'Entry by', 'Correct?', 'DOI', 'Unnamed: 13']
# Measuring Technique
# Patch-clamp                     144
# TEVC                            107
# Single-channel patch-clamp       37
# RNS                              26
# Voltage-clamp                    22
# Electrophysiology                10
# Single-channel recording          8
# Voltage-clamp                     5
# Single-channel kinetics           5
# DNA Sequencing                    4
# Single-Channel Recording          4
# Patch Clamp                       4
# Whole-cell                        3
# EMG                               3
# ACh Binding                       2
# Whole-cell Patch Clamp            2
# 125I-alpha-bgt binding            2
# RNS (3-Hz)                        2
# FMP                               2
# ...

# %%
# 1. Get the counts for each nAChR subunit
pathology_counts = df['Pathology'].value_counts(dropna=False)

# 2. Print the results clearly
print("--- Entry Counts per Pathologies ---")
print(pathology_counts)

# Optional: If you want to save this summary to a new CSV file for your records
# subunit_counts.to_csv('subunit_counts_summary.csv', header=['Count'])
# Out:
# --- Entry Counts per Pathologies ---
# Pathology
# NaN                                          194
# CMS                                           72
# SCCMS                                         35
# Nicotine Dependence                           20
# ADNFLE                                        18
# Schizophrenia                                 13
# Neuropathic Pain                               6
# Nicotine Dependence                            6
# FCCMS                                          6
# Cognitive/Neurodegenerative disorders          5
# Sporadic ALS                                   5
# Epilepsy                                       4
# AChR Deficiency                                4
# FADS / LMPS                                    4
# Nicotine dependence                            3
# SALS                                           3
# Congenital Myasthenia                          2
# Escobar syndrome                               2
# ...

# %%
# 1. Get the counts for each nAChR subunit
subunit_counts = df['nAChR subunit'].value_counts(dropna=False)

# 2. Print the results clearly
print("--- Entry Counts per nAChR Subunit ---")
print(subunit_counts)

# Optional: If you want to save this summary to a new CSV file for your records
# subunit_counts.to_csv('subunit_counts_summary.csv', header=['Count'])
# Out:
# --- Entry Counts per nAChR Subunit ---
# nAChR subunit
# CHRNA1    107
# CHRNE      80
# CHRNA7     57
# CHRND      33
# CHRNB1     23
# CHRNA6     21
# CHRNA4     21
# CHRNB4     20
# CHRNB2     17
# CHRNA2      9
# CHRNA3      9
# CHRNA5      5
# CHRNG       5
# CHRNB3      4
# CHRNA9      2
# Name: count, dtype: int64

# %%
# 1. Get the counts for each nAChR subunit
modification_counts = df['Effect'].value_counts(dropna=False)

# 2. Print the results clearly
print("--- Entry Counts per Modification type ---")
print(modification_counts)

# Optional: If you want to save this summary to a new CSV file for your records
# subunit_counts.to_csv('subunit_counts_summary.csv', header=['Count'])
# Out:
# --- Entry Counts per Modification type ---
# Effect
# LOF              245
# GOF              133
# No net effect     24
# LOF/GOF           10
# GOF                1
# Name: count, dtype: int64

# %%
# 1. Get the counts for each nAChR subunit
pathology_counts = df['Pathology'].value_counts(dropna=False)

# 2. Print the results clearly
print("--- Entry Counts per Pathologies ---")
print(pathology_counts)

# Optional: If you want to save this summary to a new CSV file for your records
# subunit_counts.to_csv('subunit_counts_summary.csv', header=['Count'])
# Out:
# --- Entry Counts per Pathologies ---
# Pathology
# NaN                                          194
# CMS                                           72
# SCCMS                                         35
# Nicotine Dependence                           20
# ADNFLE                                        18
# Schizophrenia                                 13
# Neuropathic Pain                               6
# Nicotine Dependence                            6
# FCCMS                                          6
# Cognitive/Neurodegenerative disorders          5
# Sporadic ALS                                   5
# Epilepsy                                       4
# AChR Deficiency                                4
# FADS / LMPS                                    4
# Nicotine dependence                            3
# SALS                                           3
# Congenital Myasthenia                          2
# Escobar syndrome                               2
# ...

# %%
# Load your dataframe here if needed, e.g.:
# df = pd.read_excel(r'C:\Users\harik\Downloads\Computational Chemistry\Variant-Effect-Predictor-for-nAChRs\your_original_file.xlsx')

# 1. Clean up any invisible spaces at the ends of the text
df['Measuring Technique'] = df['Measuring Technique'].astype(str).str.strip()

# 2. Create a mapping dictionary to merge the variations into the 8 suggested groups
technique_mapping = {
    # --- 1. Patch Clamp ---
    'Patch Clamp': 'Patch Clamp',
    'Single-Channel Recording': 'Patch Clamp',
    'Cell-attached Patch-clamp': 'Patch Clamp',
    'HEK cell Patch-clamp': 'Patch Clamp',
    'Single Cell Patch Clamp': 'Patch Clamp',
    'Patch-clamp': 'Patch Clamp',
    'Patch-Clamp': 'Patch Clamp',
    'Whole-cell': 'Patch Clamp',
    'Whole-cell Patch Clamp': 'Patch Clamp',
    'Whole-cell clamp': 'Patch Clamp',
    'Single-channel patch-clamp': 'Patch Clamp',
    'Single-channel recording': 'Patch Clamp',
    'Single-channel kinetics': 'Patch Clamp',
    'Single Channel': 'Patch Clamp',
    
    # --- 2. TEVC & Voltage Clamp ---
    'TEVC': 'TEVC & Voltage Clamp',
    'Voltage Clamp': 'TEVC & Voltage Clamp',
    'Voltage-clamp': 'TEVC & Voltage Clamp',
    
    # --- 3. EMG & Nerve Stimulation ---
    'Repetitive Nerve Stimulation (RNS)': 'EMG & Nerve Stimulation',
    'RNS': 'EMG & Nerve Stimulation',
    'RNS (3-Hz)': 'EMG & Nerve Stimulation',
    'Repetitive Nerve Stimulation': 'EMG & Nerve Stimulation',
    'EMG / CMAP': 'EMG & Nerve Stimulation',
    'Electromyography': 'EMG & Nerve Stimulation',
    'NCS': 'EMG & Nerve Stimulation',
    
    # --- 4. Electrophysiology (Unspecified) ---
    'Electrophysiology (Unspecified)': 'Electrophysiology (Unspecified)',
    
    # --- 5. Binding Assays ---
    'Binding Assay': 'Binding Assays',
    'Cell surface binding': 'Binding Assays',
    'ACh Binding': 'Binding Assays',
    '125I-alpha-bgt binding': 'Binding Assays',
    'Alpha-bgt binding': 'Binding Assays',
    '125 alpha BuTx binding': 'Binding Assays',
    '125 alpha BTX binding': 'Binding Assays',
    
    # --- 6. Molecular / Genetic Assays ---
    'DNA Sequencing': 'Molecular / Genetic Assays',
    'SSCA': 'Molecular / Genetic Assays',
    
    # --- 7. Fluorescence Assay ---
    'Fluorescence Assay': 'Fluorescence Assay',
    
    # --- 8. Other (Clinical/Cell) ---
    'Video-EEG': 'Other (Clinical/Cell)',
    'HEK 293 expression': 'Other (Clinical/Cell)',
    
    # --- Clean up missing values (NaN) ---
    'nan': 'Unknown'
}



# 3. Apply the mapping to your dataframe
df['Measuring Technique'] = df['Measuring Technique'].replace(technique_mapping)

# 4. Print out the newly grouped methodologies to verify!
print("--- Cleaned & Grouped Methodologies ---")
print(df['Measuring Technique'].value_counts())


# 1. Clean up any invisible spaces and standardize text
df['Pathology'] = df['Pathology'].astype(str).str.strip()

# 2. Create a mapping dictionary to merge pathology variations
pathology_mapping = {
    # --- Congenital Myasthenic Syndromes (CMS) ---
    'CMS': 'Congenital Myasthenic Syndrome (CMS)',
    'SCCMS': 'Congenital Myasthenic Syndrome (CMS)',
    'FCCMS': 'Congenital Myasthenic Syndrome (CMS)',
    'Congenital Myasthenia': 'Congenital Myasthenic Syndrome (CMS)',
    'AChR Deficiency': 'Congenital Myasthenic Syndrome (CMS)',
    'Slow-channel syndrome': 'Congenital Myasthenic Syndrome (CMS)',
    'Slow Channel Syndrome': 'Congenital Myasthenic Syndrome (CMS)',
    'FADS / LMPS': 'Congenital Myasthenic Syndrome (CMS)', # Fetal Akinesia Deformation Sequence / Lethal Multiple Pterygium Syndrome (severe prenatal CMS)
    'Escobar syndrome': 'Congenital Myasthenic Syndrome (CMS)', # A variant of CMS

    # --- Nicotine & Addiction ---
    'Nicotine Dependence': 'Nicotine Dependence & Seizures',
    'Nicotine dependence': 'Nicotine Dependence & Seizures',
    'Nicotine-induced seizures': 'Nicotine Dependence & Seizures',

    # --- Sleep-related / Frontal Lobe Epilepsies ---
    'ADNFLE': 'Sleep-related Epilepsy (SHE/ADNFLE)', # Autosomal Dominant Nocturnal Frontal Lobe Epilepsy
    'ADSHE': 'Sleep-related Epilepsy (SHE/ADNFLE)', # Autosomal Dominant Sleep-related Hyperkinetic Epilepsy
    'Sleep-related Hyperkinetic Epilepsy (SHE)': 'Sleep-related Epilepsy (SHE/ADNFLE)',
    
    # --- Other Epilepsies & Channels ---
    'Epilepsy': 'Other Epilepsies',
    'Insular Epilepsy': 'Other Epilepsies',
    'GEFS+': 'Other Epilepsies', # Generalized Epilepsy with Febrile Seizures Plus
    'PKD and GEFS+': 'Other Epilepsies', # Paroxysmal Kinesigenic Choreoathetosis with GEFS+

    # --- Neurodegenerative / Psychiatric ---
    'Schizophrenia': 'Schizophrenia',
    'Cognitive/Neurodegenerative disorders': 'Cognitive/Neurodegenerative disorders',
    'Infantile parkinsonism': 'Cognitive/Neurodegenerative disorders',
    
    # --- Amyotrophic Lateral Sclerosis (ALS) ---
    'Sporadic ALS': 'Sporadic ALS (SALS)',
    'SALS': 'Sporadic ALS (SALS)',

    # --- Pain & Other Systemic Conditions ---
    'Neuropathic Pain': 'Neuropathic Pain',
    'CAKUT, Dysautonomia': 'CAKUT & Dysautonomia', # Congenital Anomalies of the Kidney and Urinary Tract
    'Polymorphism': 'Polymorphism',

    # --- Clean up missing values (NaN) ---
    'nan': 'Unknown'
}

# 3. Apply the mapping to your dataframe
df['Pathology'] = df['Pathology'].replace(pathology_mapping)

# 4. Print out the newly grouped pathologies to verify!
print("--- Cleaned & Grouped Pathologies ---")
print(df['Pathology'].value_counts())

# 5. Save the updated dataframe to a NEW Excel file
output_path = r'C:\Users\harik\Downloads\Computational Chemistry\Variant-Effect-Predictor-for-nAChRs\nachr_db_cleaned.xlsx'
df.to_excel(output_path, index=False)

print(f"\nSuccess! Cleaned data has been saved to: {output_path}")
# Out:
# --- Cleaned & Grouped Methodologies ---
# Measuring Technique
# Patch Clamp                   215
# TEVC & Voltage Clamp          134
# EMG & Nerve Stimulation        31
# Electrophysiology              10
# Binding Assays                  8
# Molecular / Genetic Assays      5
# EMG                             3
# Other (Clinical/Cell)           2
# Xenopus oocyte expression       2
# FMP                             2
# CMAP / HEK cell expression      1
# Name: count, dtype: int64
# --- Cleaned & Grouped Pathologies ---
# Pathology
# Unknown                                  194
# Congenital Myasthenic Syndrome (CMS)     127
# Nicotine Dependence & Seizures            30
# Sleep-related Epilepsy (SHE/ADNFLE)       20
# Schizophrenia                             13
# Sporadic ALS (SALS)                        8
# Other Epilepsies                           7
# Cognitive/Neurodegenerative disorders      6
# Neuropathic Pain                           6
# ...

# %%
duplicate_cols = ['nAChR subunit', 'AA position', 'Initial AA', 'New AA']

# 2. Find the duplicates
# Using keep=False means it will show you ALL the duplicate entries, not just the second one
duplicates = df[df.duplicated(subset=duplicate_cols, keep=False)]

# Sort them so the matching pairs appear right next to each other in the output
duplicates = duplicates.sort_values(by=duplicate_cols)

print(f"--- Found {len(duplicates)} Duplicate Rows ---")

# Print the duplicates (showing the duplicate columns + a few others for context)
# We display the 'Measuring Technique' and 'Reference(PMID)' so you can see WHY there are duplicates
cols_to_show = duplicate_cols + ['Measuring Technique', 'Reference(PMID)']
print(duplicates[cols_to_show])
# Out:
# --- Found 14 Duplicate Rows ---
#     nAChR subunit AA position Initial AA New AA   Measuring Technique  \
# 279        CHRNA1         132          V      A           Patch Clamp
# 368        CHRNA1         132          V      A           Patch Clamp
# 46         CHRNA1         153          G      S           Patch Clamp
# 407        CHRNA1         153          G      S           Patch Clamp
# 273        CHRNA1         272          P      A           Patch Clamp
# 369        CHRNA1         272          P      A           Patch Clamp
# 105        CHRNA2         279          I      N           Patch Clamp
# 123        CHRNA2         279          I      N  TEVC & Voltage Clamp
# 39         CHRNA7         117          Q      F  TEVC & Voltage Clamp
# 42         CHRNA7         117          Q      F  TEVC & Voltage Clamp
# 30         CHRNA7         250          L      T           Patch Clamp
# 32         CHRNA7         250          L      T     Electrophysiology
# ...
